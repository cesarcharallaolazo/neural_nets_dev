# %%
import pandas as pd
from sklearn.cluster import KMeans
import nltk
import gensim
# Out:
# /Users/user/anaconda3/lib/python3.8/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/user/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# #### 1. importamos el dataset

# %%
df_sentiments = pd.read_csv("sentiments.csv" , delimiter=";")

# %%
df_sentiments.head()
# Out:
#                                           Sentiments Unnamed: 1
# 0            The Da Vinci Code book is just awesome.        NaN
# 1  this was the first clive cussler i've ever rea...        NaN
# 2                   i liked the Da Vinci Code a lot.        NaN
# 3                   i liked the Da Vinci Code a lot.        NaN
# 4  I liked the Da Vinci Code but it ultimatly did...        NaN

# %%
df_sentiments = df_sentiments[["Sentiments"]]

# %%
df_sentiments.head()
# Out:
#                                           Sentiments
# 0            The Da Vinci Code book is just awesome.
# 1  this was the first clive cussler i've ever rea...
# 2                   i liked the Da Vinci Code a lot.
# 3                   i liked the Da Vinci Code a lot.
# 4  I liked the Da Vinci Code but it ultimatly did...

# %%
df_sentiments.shape
# Out:
# (6918, 1)

# %% [markdown]
# #### 2. Tokenizacion

# %%
df_sentiments["words_tk"] = df_sentiments.apply(lambda row: nltk.word_tokenize(row["Sentiments"]) , axis=1)

# %%
df_sentiments.head()
# Out:
#                                           Sentiments  \
# 0            The Da Vinci Code book is just awesome.
# 1  this was the first clive cussler i've ever rea...
# 2                   i liked the Da Vinci Code a lot.
# 3                   i liked the Da Vinci Code a lot.
# 4  I liked the Da Vinci Code but it ultimatly did...
#
#                                             words_tk
# 0  [The, Da, Vinci, Code, book, is, just, awesome...
# 1  [this, was, the, first, clive, cussler, i, 've...
# 2        [i, liked, the, Da, Vinci, Code, a, lot, .]
# 3        [i, liked, the, Da, Vinci, Code, a, lot, .]
# 4  [I, liked, the, Da, Vinci, Code, but, it, ulti...

# %%
df_sentiments["tokens"] = df_sentiments.apply(lambda row: len(row["words_tk"]) , axis=1)

# %%
df_sentiments.head()
# Out:
#                                           Sentiments  \
# 0            The Da Vinci Code book is just awesome.
# 1  this was the first clive cussler i've ever rea...
# 2                   i liked the Da Vinci Code a lot.
# 3                   i liked the Da Vinci Code a lot.
# 4  I liked the Da Vinci Code but it ultimatly did...
#
#                                             words_tk  tokens
# 0  [The, Da, Vinci, Code, book, is, just, awesome...       9
# 1  [this, was, the, first, clive, cussler, i, 've...      27
# 2        [i, liked, the, Da, Vinci, Code, a, lot, .]       9
# 3        [i, liked, the, Da, Vinci, Code, a, lot, .]       9
# 4  [I, liked, the, Da, Vinci, Code, but, it, ulti...      18

# %% [markdown]
# #### 3. Remocion de Stop Words

# %%
stop_words = set(nltk.corpus.stopwords.words("english"))

# %%
def stopWords(words_list):
    filtered_sentence = []
    for w in words_list:
        if w not in stop_words:
            filtered_sentence.append(w)
    return filtered_sentence

# %%
df_sentiments["words_filtered"] = df_sentiments.apply(lambda row : stopWords(row["words_tk"]) , axis=1)

# %%
df_sentiments.head()
# Out:
#                                           Sentiments  \
# 0            The Da Vinci Code book is just awesome.
# 1  this was the first clive cussler i've ever rea...
# 2                   i liked the Da Vinci Code a lot.
# 3                   i liked the Da Vinci Code a lot.
# 4  I liked the Da Vinci Code but it ultimatly did...
#
#                                             words_tk  tokens  \
# 0  [The, Da, Vinci, Code, book, is, just, awesome...       9
# 1  [this, was, the, first, clive, cussler, i, 've...      27
# 2        [i, liked, the, Da, Vinci, Code, a, lot, .]       9
# 3        [i, liked, the, Da, Vinci, Code, a, lot, .]       9
# 4  [I, liked, the, Da, Vinci, Code, but, it, ulti...      18
#
#                                       words_filtered
# 0           [The, Da, Vinci, Code, book, awesome, .]
# 1  [first, clive, cussler, 've, ever, read, ,, ev...
# 2                   [liked, Da, Vinci, Code, lot, .]
# 3                   [liked, Da, Vinci, Code, lot, .]
# 4  [I, liked, Da, Vinci, Code, ultimatly, n't, se...

# %%
df_sentiments["tokens_word_filtered"] = df_sentiments.apply(lambda row: len(row["words_filtered"]) , axis=1)

# %%
df_sentiments.head()
# Out:
#                                           Sentiments  \
# 0            The Da Vinci Code book is just awesome.
# 1  this was the first clive cussler i've ever rea...
# 2                   i liked the Da Vinci Code a lot.
# 3                   i liked the Da Vinci Code a lot.
# 4  I liked the Da Vinci Code but it ultimatly did...
#
#                                             words_tk  tokens  \
# 0  [The, Da, Vinci, Code, book, is, just, awesome...       9
# 1  [this, was, the, first, clive, cussler, i, 've...      27
# 2        [i, liked, the, Da, Vinci, Code, a, lot, .]       9
# 3        [i, liked, the, Da, Vinci, Code, a, lot, .]       9
# 4  [I, liked, the, Da, Vinci, Code, but, it, ulti...      18
#
#                                       words_filtered  tokens_word_filtered
# 0           [The, Da, Vinci, Code, book, awesome, .]                     7
# 1  [first, clive, cussler, 've, ever, read, ,, ev...                    17
# 2                   [liked, Da, Vinci, Code, lot, .]                     6
# 3                   [liked, Da, Vinci, Code, lot, .]                     6
# 4  [I, liked, Da, Vinci, Code, ultimatly, n't, se...                    11

# %% [markdown]
# #### 4. Segundo stop removing

# %%
df_sentiments["words_tk_relevant"] = df_sentiments.apply(lambda row: [x for x in row["words_filtered"] if len(x) > 2] , axis=1)

# %%
df_sentiments.head()
# Out:
#                                           Sentiments  \
# 0            The Da Vinci Code book is just awesome.
# 1  this was the first clive cussler i've ever rea...
# 2                   i liked the Da Vinci Code a lot.
# 3                   i liked the Da Vinci Code a lot.
# 4  I liked the Da Vinci Code but it ultimatly did...
#
#                                             words_tk  tokens  \
# 0  [The, Da, Vinci, Code, book, is, just, awesome...       9
# 1  [this, was, the, first, clive, cussler, i, 've...      27
# 2        [i, liked, the, Da, Vinci, Code, a, lot, .]       9
# 3        [i, liked, the, Da, Vinci, Code, a, lot, .]       9
# 4  [I, liked, the, Da, Vinci, Code, but, it, ulti...      18
#
#                                       words_filtered  tokens_word_filtered  \
# 0           [The, Da, Vinci, Code, book, awesome, .]                     7
# 1  [first, clive, cussler, 've, ever, read, ,, ev...                    17
# 2                   [liked, Da, Vinci, Code, lot, .]                     6
# 3                   [liked, Da, Vinci, Code, lot, .]                     6
# 4  [I, liked, Da, Vinci, Code, ultimatly, n't, se...                    11
#
#                                    words_tk_relevant
# 0                  [The, Vinci, Code, book, awesome]
# 1  [first, clive, cussler, 've, ever, read, even,...
# 2                          [liked, Vinci, Code, lot]
# 3                          [liked, Vinci, Code, lot]
# 4   [liked, Vinci, Code, ultimatly, n't, seem, hold]

# %%
df_sentiments["tokens_words_relevant"] = df_sentiments.apply(lambda row: len(row["words_tk_relevant"]) , axis=1)

# %%
df_sentiments.head()
# Out:
#                                           Sentiments  \
# 0            The Da Vinci Code book is just awesome.
# 1  this was the first clive cussler i've ever rea...
# 2                   i liked the Da Vinci Code a lot.
# 3                   i liked the Da Vinci Code a lot.
# 4  I liked the Da Vinci Code but it ultimatly did...
#
#                                             words_tk  tokens  \
# 0  [The, Da, Vinci, Code, book, is, just, awesome...       9
# 1  [this, was, the, first, clive, cussler, i, 've...      27
# 2        [i, liked, the, Da, Vinci, Code, a, lot, .]       9
# 3        [i, liked, the, Da, Vinci, Code, a, lot, .]       9
# 4  [I, liked, the, Da, Vinci, Code, but, it, ulti...      18
#
#                                       words_filtered  tokens_word_filtered  \
# 0           [The, Da, Vinci, Code, book, awesome, .]                     7
# 1  [first, clive, cussler, 've, ever, read, ,, ev...                    17
# 2                   [liked, Da, Vinci, Code, lot, .]                     6
# 3                   [liked, Da, Vinci, Code, lot, .]                     6
# 4  [I, liked, Da, Vinci, Code, ultimatly, n't, se...                    11
#
#                                    words_tk_relevant  tokens_words_relevant
# 0                  [The, Vinci, Code, book, awesome]                      5
# 1  [first, clive, cussler, 've, ever, read, even,...                     13
# 2                          [liked, Vinci, Code, lot]                      4
# 3                          [liked, Vinci, Code, lot]                      4
# 4   [liked, Vinci, Code, ultimatly, n't, seem, hold]                      7

# %%
df_sentiments["words_tk_relevant_joined"] = df_sentiments.apply(lambda row: " ".join(row["words_tk_relevant"]) , axis=1)

# %%
df_sentiments.head()
# Out:
#                                           Sentiments  \
# 0            The Da Vinci Code book is just awesome.
# 1  this was the first clive cussler i've ever rea...
# 2                   i liked the Da Vinci Code a lot.
# 3                   i liked the Da Vinci Code a lot.
# 4  I liked the Da Vinci Code but it ultimatly did...
#
#                                             words_tk  tokens  \
# 0  [The, Da, Vinci, Code, book, is, just, awesome...       9
# 1  [this, was, the, first, clive, cussler, i, 've...      27
# 2        [i, liked, the, Da, Vinci, Code, a, lot, .]       9
# 3        [i, liked, the, Da, Vinci, Code, a, lot, .]       9
# 4  [I, liked, the, Da, Vinci, Code, but, it, ulti...      18
#
#                                       words_filtered  tokens_word_filtered  \
# 0           [The, Da, Vinci, Code, book, awesome, .]                     7
# 1  [first, clive, cussler, 've, ever, read, ,, ev...                    17
# 2                   [liked, Da, Vinci, Code, lot, .]                     6
# 3                   [liked, Da, Vinci, Code, lot, .]                     6
# 4  [I, liked, Da, Vinci, Code, ultimatly, n't, se...                    11
#
#                                    words_tk_relevant  tokens_words_relevant  \
# 0                  [The, Vinci, Code, book, awesome]                      5
# 1  [first, clive, cussler, 've, ever, read, even,...                     13
# 2                          [liked, Vinci, Code, lot]                      4
# 3                          [liked, Vinci, Code, lot]                      4
# 4   [liked, Vinci, Code, ultimatly, n't, seem, hold]                      7
#
#                             words_tk_relevant_joined
# 0                        The Vinci Code book awesome
# 1  first clive cussler 've ever read even books l...
# 2                               liked Vinci Code lot
# 3                               liked Vinci Code lot
# 4           liked Vinci Code ultimatly n't seem hold

# %% [markdown]
# #### 5. Word2Vec Process

# %%
model_w2v = gensim.models.Word2Vec(df_sentiments.words_tk_relevant.values.tolist() , min_count=0 , vector_size=5 , sg=1)

# %%
def avgVectorSentece(list_word, model):
    vector = [model_w2v.wv[x] for x in list_word]
    return sum(vector)/len(vector)

# %%
df_sentiments["result_w2v"] = df_sentiments.apply(lambda row: avgVectorSentece(row["words_tk_relevant"] , model_w2v) , axis=1)

# %%
df_sentiments.head()
# Out:
#                                           Sentiments  \
# 0            The Da Vinci Code book is just awesome.
# 1  this was the first clive cussler i've ever rea...
# 2                   i liked the Da Vinci Code a lot.
# 3                   i liked the Da Vinci Code a lot.
# 4  I liked the Da Vinci Code but it ultimatly did...
#
#                                             words_tk  tokens  \
# 0  [The, Da, Vinci, Code, book, is, just, awesome...       9
# 1  [this, was, the, first, clive, cussler, i, 've...      27
# 2        [i, liked, the, Da, Vinci, Code, a, lot, .]       9
# 3        [i, liked, the, Da, Vinci, Code, a, lot, .]       9
# 4  [I, liked, the, Da, Vinci, Code, but, it, ulti...      18
#
#                                       words_filtered  tokens_word_filtered  \
# 0           [The, Da, Vinci, Code, book, awesome, .]                     7
# 1  [first, clive, cussler, 've, ever, read, ,, ev...                    17
# 2                   [liked, Da, Vinci, Code, lot, .]                     6
# 3                   [liked, Da, Vinci, Code, lot, .]                     6
# 4  [I, liked, Da, Vinci, Code, ultimatly, n't, se...                    11
#
#                                    words_tk_relevant  tokens_words_relevant  \
# 0                  [The, Vinci, Code, book, awesome]                      5
# 1  [first, clive, cussler, 've, ever, read, even,...                     13
# 2                          [liked, Vinci, Code, lot]                      4
# 3                          [liked, Vinci, Code, lot]                      4
# 4   [liked, Vinci, Code, ultimatly, n't, seem, hold]                      7
#
#                             words_tk_relevant_joined  \
# 0                        The Vinci Code book awesome
# 1  first clive cussler 've ever read even books l...
# 2                               liked Vinci Code lot
# 3                               liked Vinci Code lot
# 4           liked Vinci Code ultimatly n't seem hold
#
#                                           result_w2v
# 0  [0.25692824, 1.6083925, -0.08842452, -0.454953...
# 1  [0.3124121, 1.0235685, 0.48780698, -0.32405186...
# 2  [0.9609831, 1.4148765, 0.42268047, -0.05549311...
# 3  [0.9609831, 1.4148765, 0.42268047, -0.05549311...
# 4  [0.56878424, 1.1457283, 0.37263504, 0.05806257...

# %% [markdown]
# #### 6. Clustering de vectores de oraciones

# %%
kmeans = KMeans(n_clusters=400 , random_state=1).fit(df_sentiments.result_w2v.tolist())

# %%
df_sentiments["predicted_cluster"] = df_sentiments.apply(lambda row: kmeans.predict([row["result_w2v"].tolist()])[0] , axis=1)

# %%
df_sentiments.sort_values("predicted_cluster").head(40)
# Out:
#                                              Sentiments  \
# 77                            i LOVE the da vinci code!
# 5078                                Harry Potter sucks.
# 5135                                Harry Potter sucks.
# 5122                                Harry Potter sucks.
# 5144                             . Harry Potter sucks..
# 5069                                Harry Potter sucks.
# 5065                                Harry Potter sucks.
# 6664       So Brokeback Mountain was really depressing.
# 6111  I'd just like to say that Brokeback Mountain i...
# 6754       So Brokeback Mountain was really depressing.
# 6634       So Brokeback Mountain was really depressing.
# 6834       So Brokeback Mountain was really depressing.
# 6154       So Brokeback Mountain was really depressing.
# 6254       So Brokeback Mountain was really depressing.
# 6334       So Brokeback Mountain was really depressing.
# 6064  I thought Brokeback Mountain was a terrible mo...
# 6744       So Brokeback Mountain was really depressing.
# 6854       So Brokeback Mountain was really depressing.
# 6524       So Brokeback Mountain was really depressing.
# 6644       So Brokeback Mountain was really depressing.
# 6624       So Brokeback Mountain was really depressing.
# 6844       So Brokeback Mountain was really depressing.
# 6654       So Brokeback Mountain was really depressing.
# 5950  But Brokeback Mountain is one of the most bori...
# 6164       So Brokeback Mountain was really depressing.
# 6274       So Brokeback Mountain was really depressing.
# 6794       So Brokeback Mountain was really depressing.
# 6384       So Brokeback Mountain was really depressing.
# 6174       So Brokeback Mountain was really depressing.
# 5961  brokeback mountain sucked everybody's mother's...
# 6674       So Brokeback Mountain was really depressing.
# 6564       So Brokeback Mountain was really depressing.
# 6554       So Brokeback Mountain was really depressing.
# 6264       So Brokeback Mountain was really depressing.
# 6494       So Brokeback Mountain was really depressing.
# 6574       So Brokeback Mountain was really depressing.
# 6784       So Brokeback Mountain was really depressing.
# 6364       So Brokeback Mountain was really depressing.
# 6424       So Brokeback Mountain was really depressing.
# 6544       So Brokeback Mountain was really depressing.
#
#                                                words_tk  tokens  \
# 77                   [i, LOVE, the, da, vinci, code, !]       7
# 5078                          [Harry, Potter, sucks, .]       4
# 5135                          [Harry, Potter, sucks, .]       4
# 5122                          [Harry, Potter, sucks, .]       4
# 5144                      [., Harry, Potter, sucks, ..]       5
# 5069                          [Harry, Potter, sucks, .]       4
# 5065                          [Harry, Potter, sucks, .]       4
# 6664  [So, Brokeback, Mountain, was, really, depress...       7
# 6111  [I, 'd, just, like, to, say, that, Brokeback, ...      15
# 6754  [So, Brokeback, Mountain, was, really, depress...       7
# 6634  [So, Brokeback, Mountain, was, really, depress...       7
# 6834  [So, Brokeback, Mountain, was, really, depress...       7
# 6154  [So, Brokeback, Mountain, was, really, depress...       7
# 6254  [So, Brokeback, Mountain, was, really, depress...       7
# 6334  [So, Brokeback, Mountain, was, really, depress...       7
# 6064  [I, thought, Brokeback, Mountain, was, a, terr...       9
# 6744  [So, Brokeback, Mountain, was, really, depress...       7
# 6854  [So, Brokeback, Mountain, was, really, depress...       7
# 6524  [So, Brokeback, Mountain, was, really, depress...       7
# 6644  [So, Brokeback, Mountain, was, really, depress...       7
# 6624  [So, Brokeback, Mountain, was, really, depress...       7
# 6844  [So, Brokeback, Mountain, was, really, depress...       7
# 6654  [So, Brokeback, Mountain, was, really, depress...       7
# 5950  [But, Brokeback, Mountain, is, one, of, the, m...      15
# 6164  [So, Brokeback, Mountain, was, really, depress...       7
# 6274  [So, Brokeback, Mountain, was, really, depress...       7
# 6794  [So, Brokeback, Mountain, was, really, depress...       7
# 6384  [So, Brokeback, Mountain, was, really, depress...       7
# 6174  [So, Brokeback, Mountain, was, really, depress...       7
# 5961  [brokeback, mountain, sucked, everybody, 's, m...       9
# 6674  [So, Brokeback, Mountain, was, really, depress...       7
# 6564  [So, Brokeback, Mountain, was, really, depress...       7
# 6554  [So, Brokeback, Mountain, was, really, depress...       7
# 6264  [So, Brokeback, Mountain, was, really, depress...       7
# 6494  [So, Brokeback, Mountain, was, really, depress...       7
# 6574  [So, Brokeback, Mountain, was, really, depress...       7
# 6784  [So, Brokeback, Mountain, was, really, depress...       7
# 6364  [So, Brokeback, Mountain, was, really, depress...       7
# 6424  [So, Brokeback, Mountain, was, really, depress...       7
# 6544  [So, Brokeback, Mountain, was, really, depress...       7
#
#                                          words_filtered  tokens_word_filtered  \
# 77                           [LOVE, da, vinci, code, !]                     5
# 5078                          [Harry, Potter, sucks, .]                     4
# 5135                          [Harry, Potter, sucks, .]                     4
# 5122                          [Harry, Potter, sucks, .]                     4
# 5144                      [., Harry, Potter, sucks, ..]                     5
# 5069                          [Harry, Potter, sucks, .]                     4
# 5065                          [Harry, Potter, sucks, .]                     4
# 6664   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6111  [I, 'd, like, say, Brokeback, Mountain, depres...                     9
# 6754   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6634   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6834   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6154   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6254   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6334   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6064  [I, thought, Brokeback, Mountain, terrible, mo...                     7
# 6744   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6854   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6524   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6644   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6624   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6844   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6654   [So, Brokeback, Mountain, really, depressing, .]                     6
# 5950  [But, Brokeback, Mountain, one, boring, movies...                    10
# 6164   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6274   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6794   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6384   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6174   [So, Brokeback, Mountain, really, depressing, .]                     6
# 5961  [brokeback, mountain, sucked, everybody, 's, m...                     9
# 6674   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6564   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6554   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6264   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6494   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6574   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6784   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6364   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6424   [So, Brokeback, Mountain, really, depressing, .]                     6
# 6544   [So, Brokeback, Mountain, really, depressing, .]                     6
#
#                                       words_tk_relevant  \
# 77                                  [LOVE, vinci, code]
# 5078                             [Harry, Potter, sucks]
# 5135                             [Harry, Potter, sucks]
# 5122                             [Harry, Potter, sucks]
# 5144                             [Harry, Potter, sucks]
# 5069                             [Harry, Potter, sucks]
# 5065                             [Harry, Potter, sucks]
# 6664          [Brokeback, Mountain, really, depressing]
# 6111  [like, say, Brokeback, Mountain, depressing, m...
# 6754          [Brokeback, Mountain, really, depressing]
# 6634          [Brokeback, Mountain, really, depressing]
# 6834          [Brokeback, Mountain, really, depressing]
# 6154          [Brokeback, Mountain, really, depressing]
# 6254          [Brokeback, Mountain, really, depressing]
# 6334          [Brokeback, Mountain, really, depressing]
# 6064    [thought, Brokeback, Mountain, terrible, movie]
# 6744          [Brokeback, Mountain, really, depressing]
# 6854          [Brokeback, Mountain, really, depressing]
# 6524          [Brokeback, Mountain, really, depressing]
# 6644          [Brokeback, Mountain, really, depressing]
# 6624          [Brokeback, Mountain, really, depressing]
# 6844          [Brokeback, Mountain, really, depressing]
# 6654          [Brokeback, Mountain, really, depressing]
# 5950  [But, Brokeback, Mountain, one, boring, movies...
# 6164          [Brokeback, Mountain, really, depressing]
# 6274          [Brokeback, Mountain, really, depressing]
# 6794          [Brokeback, Mountain, really, depressing]
# 6384          [Brokeback, Mountain, really, depressing]
# 6174          [Brokeback, Mountain, really, depressing]
# 5961  [brokeback, mountain, sucked, everybody, mothe...
# 6674          [Brokeback, Mountain, really, depressing]
# 6564          [Brokeback, Mountain, really, depressing]
# 6554          [Brokeback, Mountain, really, depressing]
# 6264          [Brokeback, Mountain, really, depressing]
# 6494          [Brokeback, Mountain, really, depressing]
# 6574          [Brokeback, Mountain, really, depressing]
# 6784          [Brokeback, Mountain, really, depressing]
# 6364          [Brokeback, Mountain, really, depressing]
# 6424          [Brokeback, Mountain, really, depressing]
# 6544          [Brokeback, Mountain, really, depressing]
#
#       tokens_words_relevant  \
# 77                        3
# 5078                      3
# 5135                      3
# 5122                      3
# 5144                      3
# 5069                      3
# 5065                      3
# 6664                      4
# 6111                      6
# 6754                      4
# 6634                      4
# 6834                      4
# 6154                      4
# 6254                      4
# 6334                      4
# 6064                      5
# 6744                      4
# 6854                      4
# 6524                      4
# 6644                      4
# 6624                      4
# 6844                      4
# 6654                      4
# 5950                      8
# 6164                      4
# 6274                      4
# 6794                      4
# 6384                      4
# 6174                      4
# 5961                      6
# 6674                      4
# 6564                      4
# 6554                      4
# 6264                      4
# 6494                      4
# 6574                      4
# 6784                      4
# 6364                      4
# 6424                      4
# 6544                      4
#
#                                words_tk_relevant_joined  \
# 77                                      LOVE vinci code
# 5078                                 Harry Potter sucks
# 5135                                 Harry Potter sucks
# 5122                                 Harry Potter sucks
# 5144                                 Harry Potter sucks
# 5069                                 Harry Potter sucks
# 5065                                 Harry Potter sucks
# 6664               Brokeback Mountain really depressing
# 6111       like say Brokeback Mountain depressing movie
# 6754               Brokeback Mountain really depressing
# 6634               Brokeback Mountain really depressing
# 6834               Brokeback Mountain really depressing
# 6154               Brokeback Mountain really depressing
# 6254               Brokeback Mountain really depressing
# 6334               Brokeback Mountain really depressing
# 6064          thought Brokeback Mountain terrible movie
# 6744               Brokeback Mountain really depressing
# 6854               Brokeback Mountain really depressing
# 6524               Brokeback Mountain really depressing
# 6644               Brokeback Mountain really depressing
# 6624               Brokeback Mountain really depressing
# 6844               Brokeback Mountain really depressing
# 6654               Brokeback Mountain really depressing
# 5950  But Brokeback Mountain one boring movies ever ...
# 6164               Brokeback Mountain really depressing
# 6274               Brokeback Mountain really depressing
# 6794               Brokeback Mountain really depressing
# 6384               Brokeback Mountain really depressing
# 6174               Brokeback Mountain really depressing
# 5961   brokeback mountain sucked everybody mother balls
# 6674               Brokeback Mountain really depressing
# 6564               Brokeback Mountain really depressing
# 6554               Brokeback Mountain really depressing
# 6264               Brokeback Mountain really depressing
# 6494               Brokeback Mountain really depressing
# 6574               Brokeback Mountain really depressing
# 6784               Brokeback Mountain really depressing
# 6364               Brokeback Mountain really depressing
# 6424               Brokeback Mountain really depressing
# 6544               Brokeback Mountain really depressing
#
#                                              result_w2v  predicted_cluster
# 77    [1.429567, 1.2159837, -0.18167357, -1.0443093,...                  0
# 5078  [-0.57239026, 1.1760925, 1.2163883, -0.7332012...                  1
# 5135  [-0.57239026, 1.1760925, 1.2163883, -0.7332012...                  1
# 5122  [-0.57239026, 1.1760925, 1.2163883, -0.7332012...                  1
# 5144  [-0.57239026, 1.1760925, 1.2163883, -0.7332012...                  1
# 5069  [-0.57239026, 1.1760925, 1.2163883, -0.7332012...                  1
# 5065  [-0.57239026, 1.1760925, 1.2163883, -0.7332012...                  1
# 6664  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6111  [0.13858767, 1.1235873, 0.26044187, -1.0612671...                  2
# 6754  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6634  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6834  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6154  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6254  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6334  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6064  [0.14196002, 1.0807452, 0.30076087, -1.3145458...                  2
# 6744  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6854  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6524  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6644  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6624  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6844  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6654  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 5950  [0.0774315, 1.2235793, 0.25496715, -1.2264936,...                  2
# 6164  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6274  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6794  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6384  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6174  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 5961  [0.24094532, 1.1895574, 0.17025726, -1.1181618...                  2
# 6674  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6564  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6554  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6264  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6494  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6574  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6784  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6364  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6424  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2
# 6544  [0.13791016, 1.0707715, 0.33869937, -1.2424672...                  2

# %%
df_sentiments.shape
# Out:
# (6918, 10)

# %%
#df_sentiments[["Sentiments" , "words_tk_relevant_joined" , "predicted_cluster"]].to_csv("Clustering_Sentiments.csv" , sep="\t" , header=True , index=False)
